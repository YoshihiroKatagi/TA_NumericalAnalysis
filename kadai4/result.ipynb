# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
#絶対誤差
filename = "AbsoluteError.csv"
df = pd.read_csv(filename)
df
# Out:
#         n  trapezoidal  midpoint    simpson
# 0      50    38.227546  1.772454  11.560879
# 1      60    31.560879  1.772454   9.338657
# 2      70    26.798975  1.772454   7.751356
# 3      80    23.227546  1.772454   6.560879
# 4      90    20.449768  1.772454   5.634954
# ..    ...          ...       ...        ...
# 141  1460     0.018426  0.018426   0.006142
# 142  1470     0.017141  0.017141   0.005714
# 143  1480     0.015937  0.015937   0.005312
# 144  1490     0.014811  0.014811   0.004937
# 145  1500     0.013758  0.013758   0.004586
#
# [146 rows x 4 columns]

# %%
plt.plot(df["n"], df["trapezoidal"], label="trapezoidal")
plt.plot(df["n"], df["midpoint"], label="midpoint")
plt.plot(df["n"], df["simpson"], label="simpson")
plt.title("Absolute Error")
plt.xlabel("Divide Number")
plt.ylabel("Value")
plt.legend()
plt.savefig("AbsoluteError.png")
plt.show()

# %%
#相対誤差
filename = "RelativeError.csv"
df = pd.read_csv(filename)
df
# Out:
#         n  trapezoidal  midpoint   simpson
# 0      50    21.567583  1.000000  6.522528
# 1      60    17.806319  1.000000  5.268773
# 2      70    15.119702  1.000000  4.373234
# 3      80    13.104740  1.000000  3.701580
# 4      90    11.537546  1.000000  3.179182
# ..    ...          ...       ...       ...
# 141  1460     0.010396  0.010396  0.003465
# 142  1470     0.009671  0.009671  0.003224
# 143  1480     0.008992  0.008992  0.002997
# 144  1490     0.008356  0.008356  0.002785
# 145  1500     0.007762  0.007762  0.002587
#
# [146 rows x 4 columns]

# %%
plt.plot(df["n"], df["trapezoidal"], label="trapezoidal")
plt.plot(df["n"], df["midpoint"], label="midpoint")
plt.plot(df["n"], df["simpson"], label="simpson")
plt.title("Relative Error")
plt.xlabel("Divide Number")
plt.ylabel("Value")
plt.legend()
plt.savefig("RelativeError.png")
plt.show()
